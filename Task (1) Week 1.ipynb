# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd

df = pd.read_csv('Dataset.csv')

# %% [markdown]
# ### Handle Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12311    False
# 12312    False
# 12313    False
# 12314    False
# 12315    False
# Length: 12316, dtype: bool

# %%
df[df.duplicated()]
df.duplicated().sum()
# Out:
# 0

# %%
df.sort_values(by='Time', ascending=False)#.drop_duplicates(subset=['Name', 'Age'])# inplace=True
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 5566   9:59:00     Tuesday            Over 51          Male
# 5567   9:59:00     Tuesday            Unknown          Male
# 9072   9:58:00    Saturday              31-50          Male
# 11966  9:57:00    Thursday            Over 51        Female
# 2178   9:57:00   Wednesday              18-30          Male
# ...        ...         ...                ...           ...
# 8933   0:01:00    Saturday              18-30          Male
# 8932   0:01:00    Saturday              18-30          Male
# 8647   0:01:00      Friday              31-50          Male
# 8931   0:01:00    Saturday              18-30          Male
# 8934   0:01:00    Saturday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 5566              Unknown                Employee         Above 10yr
# 5567    Elementary school                Employee             5-10yr
# ...

# %%
df.isnull()
# Out:
#         Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0      False        False               False          False
# 1      False        False               False          False
# 2      False        False               False          False
# 3      False        False               False          False
# 4      False        False               False          False
# ...      ...          ...                 ...            ...
# 12311  False        False               False          False
# 12312  False        False               False          False
# 12313  False        False               False          False
# 12314  False        False               False          False
# 12315  False        False               False          False
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                  False                    False               False
# 1                  False                    False               False
# ...

# %%
df[~df.isnull().any(axis=1)]
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 8      17:20:00      Friday              18-30          Male
# 9      17:20:00      Friday              18-30          Male
# 12     17:45:00    Thursday              18-30          Male
# 13     17:45:00    Thursday              31-50          Male
# 14     17:45:00    Thursday              31-50          Male
# ...         ...         ...                ...           ...
# 12302  17:25:00      Friday              31-50          Male
# 12303  12:48:00      Friday              31-50          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 8      Junior high school                Employee         Above 10yr
# 9      Junior high school                Employee              1-2yr
# ...

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df['Casualty_severity'] = pd.to_numeric(df['Casualty_severity'], errors='coerce')

df['Casualty_severity'].fillna(df['Casualty_severity'].mean(), inplace=True)

df['Educational_level'].fillna(method='bfill', inplace=True)
df['Educational_level'].fillna(method='ffill', inplace=True)

df['Vehicle_driver_relation'].fillna(method='bfill', inplace=True)
df['Vehicle_driver_relation'].fillna(method='ffill', inplace=True)

df['Driving_experience'].fillna(method='bfill', inplace=True)
df['Driving_experience'].fillna(method='ffill', inplace=True)

df.dropna(subset=['Sex_of_casualty'], inplace=True)
# Out:
# /var/folders/3p/0bjvqt397999zpl674n8ls340000gn/T/ipykernel_11770/2118324802.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Casualty_severity'].fillna(df['Casualty_severity'].mean(), inplace=True)
# /var/folders/3p/0bjvqt397999zpl674n8ls340000gn/T/ipykernel_11770/2118324802.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull()
# Out:
#         Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0      False        False               False          False
# 1      False        False               False          False
# 2      False        False               False          False
# 3      False        False               False          False
# 4      False        False               False          False
# ...      ...          ...                 ...            ...
# 12311  False        False               False          False
# 12312  False        False               False          False
# 12313  False        False               False          False
# 12314  False        False               False          False
# 12315  False        False               False          False
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                  False                    False               False
# 1                  False                    False               False
# ...

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
for column in df.columns:
    unique_values = df[column].unique()
    print(f"'{column}': {unique_values}\n")
# Out:
# 'Time': ['17:02:00' '1:06:00' '14:15:00' ... '7:24:00' '19:18:00' '2:47:00']
#
# 'Day_of_week': ['Monday' 'Sunday' 'Friday' 'Wednesday' 'Saturday' 'Thursday' 'Tuesday']
#
# 'Age_band_of_driver': ['18-30' '31-50' 'Under 18' 'Over 51' 'Unknown']
#
# 'Sex_of_driver': ['Male' 'Female' 'Unknown']
#
# 'Educational_level': ['Above high school' 'Junior high school' 'Elementary school'
#  'High school' 'Unknown' 'Illiterate' 'Writing & reading']
#
# 'Vehicle_driver_relation': ['Employee' 'Unknown' 'Owner' 'Other']
#
# 'Driving_experience': ['1-2yr' 'Above 10yr' '5-10yr' '2-5yr' 'No Licence' 'Below 1yr' 'unknown']
#
# 'Type_of_vehicle': ['Automobile' 'Public (> 45 seats)' 'Lorry (41?100Q)' nan
#  'Public (13?45 seats)' 'Lorry (11?40Q)' 'Long lorry' 'Public (12 seats)'
#  'Taxi' 'Pick up upto 10Q' 'Stationwagen' 'Ridden horse' 'Other' 'Bajaj'
#  'Turbo' 'Motorcycle' 'Special vehicle' 'Bicycle']
#
# 'Owner_of_vehicle': ['Owner' 'Governmental' nan 'Organization' 'Other']
#
# ...

# %%
import numpy as np


df.replace(['na', 'Na', 'nA', 'NA', 'nan', 'Nan', 'nAn', 'NAn', 'naN', 'NaN', 'nAN', 'NAN'], np.nan, inplace=True)

df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.dtypes
#FYI, I converted an object type earlier for casualty severity so i can get the mean of them.
# Out:
# Time                            object
# Day_of_week                     object
# Age_band_of_driver              object
# Sex_of_driver                   object
# Educational_level               object
# Vehicle_driver_relation         object
# Driving_experience              object
# Type_of_vehicle                 object
# Owner_of_vehicle                object
# Service_year_of_vehicle         object
# Defect_of_vehicle               object
# Area_accident_occured           object
# Lanes_or_Medians                object
# Road_allignment                 object
# Types_of_Junction               object
# Road_surface_type               object
# Road_surface_conditions         object
# Light_conditions                object
# Weather_conditions              object
# Type_of_collision               object
# Number_of_vehicles_involved      int64
# Number_of_casualties             int64
# Vehicle_movement                object
# Casualty_class                  object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.groupby('Number_of_vehicles_involved')[['Number_of_casualties', 'Casualty_severity']].agg(['min', 'max'])
# Out:
#                             Number_of_casualties     Casualty_severity
#                                              min max               min  max
# Number_of_vehicles_involved
# 1                                              1   4               1.0  3.0
# 2                                              1   8               1.0  3.0
# 3                                              1   6               1.0  3.0
# 4                                              1   7               1.0  3.0
# 6                                              1   2               2.0  3.0
# 7                                              1   1               2.0  3.0

# %%
df.agg({'Number_of_vehicles_involved':'max',
            'Number_of_casualties':'min'})
# Out:
# Number_of_vehicles_involved    7
# Number_of_casualties           1
# dtype: int64

# %%
df.groupby(['Number_of_vehicles_involved', 'Casualty_severity'])['Number_of_casualties'].mean()
# Out:
# Number_of_vehicles_involved  Casualty_severity
# 1                            1.000000             1.000000
#                              2.000000             1.282443
#                              2.895466             1.261708
#                              3.000000             1.251101
# 2                            1.000000             1.300000
#                              2.000000             1.494382
#                              2.895466             1.485185
#                              3.000000             1.519726
# 3                            1.000000             3.000000
#                              2.000000             1.963415
#                              2.895466             1.903333
#                              3.000000             1.977401
# 4                            1.000000             3.000000
#                              2.000000             2.900000
#                              2.895466             2.362903
# ...

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties  Casualty_severity
# count                 12316.000000          12316.000000       12316.000000
# mean                      2.040679              1.548149           2.895466
# std                       0.688790              1.007179           0.253112
# min                       1.000000              1.000000           1.000000
# 25%                       2.000000              1.000000           2.895466
# 50%                       2.000000              1.000000           3.000000
# 75%                       2.000000              2.000000           3.000000
# max                       7.000000              8.000000           3.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df['Time'] = pd.to_datetime(df['Time']).dt.hour * 3600 + pd.to_datetime(df['Time']).dt.minute * 60 + pd.to_datetime(df['Time']).dt.second

numeric_cols = df.select_dtypes(include=[np.number]).columns
df_numeric = df[numeric_cols]


df_numeric.corr()
# Out:
#                              Time  Number_of_vehicles_involved  \
# Time                          NaN                          NaN
# Number_of_vehicles_involved   NaN                     1.000000
# Number_of_casualties          NaN                     0.213427
# Casualty_severity             NaN                     0.011033
#
#                              Number_of_casualties  Casualty_severity
# Time                                          NaN                NaN
# Number_of_vehicles_involved              0.213427           0.011033
# Number_of_casualties                     1.000000           0.006255
# Casualty_severity                        0.006255           1.000000

# %% [markdown]
# Number of vehicles involved and number of casualties (0.21): There is a low positive correlation, indicating that more vehicles involved in an accident slightly increase the number of casualties.
# Casualty severity and other variables: There is a very weak or negligible correlation with other variables, suggesting that the severity of casualties is not strongly linked to the number of vehicles involved or the number of casualties.

# %%
unique_values = df.select_dtypes(include=['object']).apply(lambda col: col.unique())
print(unique_values)
# Out:
# Day_of_week                [Monday, Sunday, Friday, Wednesday, Saturday, ...
# Age_band_of_driver                [18-30, 31-50, Under 18, Over 51, Unknown]
# Sex_of_driver                                        [Male, Female, Unknown]
# Educational_level          [Above high school, Junior high school, Elemen...
# Vehicle_driver_relation                    [Employee, Unknown, Owner, Other]
# Driving_experience         [1-2yr, Above 10yr, 5-10yr, 2-5yr, No Licence,...
# Type_of_vehicle            [Automobile, Public (> 45 seats), Lorry (41?10...
# Owner_of_vehicle             [Owner, Governmental, nan, Organization, Other]
# Service_year_of_vehicle    [Above 10yr, 5-10yrs, nan, 1-2yr, 2-5yrs, Unkn...
# Defect_of_vehicle                                     [No defect, nan, 7, 5]
# Area_accident_occured      [Residential areas, Office areas,   Recreation...
# Lanes_or_Medians           [nan, Undivided Two way, other, Double carriag...
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.countplot(x='Age_band_of_driver', data=df, hue='Age_band_of_driver')
plt.title('Distribution of Age Band of Driver')
plt.xlabel('Age Band of Driver')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(10, 5))
sns.countplot(x='Type_of_vehicle', data=df, hue='Type_of_vehicle')
ax = plt.gca()

ax.set_xticklabels(ax.get_xticklabels(), rotation=50, ha="right")

plt.title('Distribution of Type of Vehicle')
plt.xlabel('Type of Vehicle')
plt.ylabel('Count')
plt.show()
# Out:
# /var/folders/3p/0bjvqt397999zpl674n8ls340000gn/T/ipykernel_11770/1187353611.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=50, ha="right")

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df.groupby('Age_band_of_driver')['Accident_severity'].value_counts().unstack()
# Out:
# Accident_severity   Fatal injury  Serious Injury  Slight Injury
# Age_band_of_driver
# 18-30                         62             604           3605
# 31-50                         54             541           3492
# Over 51                       24             257           1304
# Under 18                      12             169            644
# Unknown                        6             172           1370

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
# Histogram 
plt.figure(figsize=(10, 5))
sns.histplot(df['Service_year_of_vehicle'], bins=10, kde=True)
plt.title('Histogram of Service Year of Vehicle')
plt.xlabel('Service Year of Vehicle')
plt.ylabel('Frequency')
plt.show()

# Bar Chart 
plt.figure(figsize=(10, 5))
sns.countplot(x='Age_band_of_driver', data=df, hue='Age_band_of_driver')
plt.title('Bar Chart of Age Band of Driver')
plt.xlabel('Age Band of Driver')
plt.ylabel('Count')
plt.show()

# Pie Chart
plt.figure(figsize=(8, 8))
df['Type_of_vehicle'].value_counts().plot.pie( colors=sns.color_palette('viridis'))
plt.title('Pie Chart of Type of Vehicle')
plt.ylabel('')
plt.show()

# Scatter Plot 
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Service_year_of_vehicle', y='Number_of_casualties', data=df, hue='Accident_severity', palette='viridis')
plt.title('Scatter Plot of Service Year of Vehicle vs Number of Casualties')
plt.xlabel('Service Year of Vehicle')
plt.ylabel('Number of Casualties')
plt.show()

# Heatmap 
cross_tab = pd.crosstab(df['Age_band_of_driver'], df['Accident_severity'])
plt.figure(figsize=(10, 5))
sns.heatmap(cross_tab, annot=True, cmap='YlGnBu')
plt.title('Heatmap of Age Band of Driver vs Accident Severity')
plt.xlabel('Accident Severity')
plt.ylabel('Age Band of Driver')
plt.show()

# %%
sns.pairplot(df);

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# Bar chart
# The bar chart shows the count of the age of the drivers, where it shows people from 18-30 have the maximum number where as the people aged 50 are less.
#
# Pie Chart of Type of Vehicle
# This pie chart shows the different types of vehicles involved in traffic data. Each slice represents a different vehicle type, and the size of the slice shows how common that vehicle type is compared to others.
#
# Scatter Plot of Service Year of Vehicle vs. Number of Casualties
# the plot shows the relationship between the age of vehicles and the number of casualties in accidents. Each dot represents an accident, with the color indicating the severity of the accident.
#
# Heatmap of Age Band of Driver vs. Accident Severity
# This heatmap shows how often drivers of different age groups are involved in accidents of varying severity. The numbers and colors indicate how many accidents occurred, with darker colors representing more accidents.
#
# Histogram of Service Year of Vehicle
# This graph displays the frequency of vehicles based on how many years they have been in service. The height of each bar shows how many vehicles fall into each age category, and the line overlay shows the density distribution.
